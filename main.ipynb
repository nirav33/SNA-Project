# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from scholarly import scholarly
from itertools import combinations

# %%
def extract_scholar_profile(scholar_id):
    """Extract single scholar profile and their coauthors"""
    try:
        author = scholarly.search_author_id(scholar_id)
        author = scholarly.fill(author)
        return {
            "name": author.get("name", "N/A"),
            "scholar_id": scholar_id,
            "affiliation": author.get("affiliation", "N/A"),
            "coauthors": author.get("coauthors", [])
        }
    except Exception as e:
        print(f"Error retrieving data for ID {scholar_id}: {e}")
        return None

# %%
def create_individual_network(profile):
    """Create network for a single professor"""
    if not profile:
        return None
    
    G = nx.Graph()
    prof_name = profile["name"]
    
    # Add professor as central node
    G.add_node(prof_name, node_type="professor")
    
    # Add coauthors and connections
    for coauthor in profile["coauthors"]:
        coauthor_name = coauthor["name"]
        G.add_node(coauthor_name, node_type="coauthor")
        G.add_edge(prof_name, coauthor_name)
    
    return G

# %%
def visualize_individual_network(G, professor_name):
    """Visualize network for a single professor"""
    if not G:
        return
    
    plt.figure(figsize=(12, 8))
    pos = nx.spring_layout(G, k=1)
    
    # Draw nodes with different colors for professor and coauthors
    node_colors = ['red' if G.nodes[node]['node_type'] == "professor" else 'lightblue' 
                  for node in G.nodes()]
    
    nx.draw(G, pos,
            node_color=node_colors,
            node_size=[3000 if G.nodes[node]['node_type'] == "professor" else 1000 
                      for node in G.nodes()],
            with_labels=True,
            font_size=8,
            edge_color='gray',
            alpha=0.7)
    
    plt.title(f"Collaboration Network - {professor_name}")
    plt.savefig(f"individual_network_{professor_name.replace(' ', '_')}.png", 
                bbox_inches='tight')
    plt.close()

# %%
def find_shared_connections(profiles):
    """Create network showing connections shared between professors"""
    G = nx.Graph()
    
    # Dictionary to store each professor's coauthors
    prof_coauthors = {}
    
    # Collect all coauthors for each professor
    for profile in profiles:
        if profile:
            prof_name = profile["name"]
            coauthors = set(coauthor["name"] for coauthor in profile["coauthors"])
            prof_coauthors[prof_name] = coauthors
            
            # Add professor node
            G.add_node(prof_name, node_type="professor")
    
    # Find shared connections between professors
    for (prof1, coauthors1), (prof2, coauthors2) in combinations(prof_coauthors.items(), 2):
        shared = coauthors1.intersection(coauthors2)
        if shared:
            # Add edge between professors with shared connections
            G.add_edge(prof1, prof2, weight=len(shared), shared_coauthors=list(shared))
            
            # Add shared coauthor nodes and their connections
            for coauthor in shared:
                G.add_node(coauthor, node_type="shared_coauthor")
                G.add_edge(prof1, coauthor)
                G.add_edge(prof2, coauthor)
    
    return G

# %%
def visualize_shared_network(G):
    """Visualize network of shared connections"""
    if not G or G.number_of_edges() == 0:
        print("No shared connections found between professors")
        return
    
    plt.figure(figsize=(15, 10))
    pos = nx.spring_layout(G, k=1)
    
    # Draw nodes with different colors for professors and shared coauthors
    node_colors = []
    node_sizes = []
    for node in G.nodes():
        if G.nodes[node]['node_type'] == "professor":
            node_colors.append('red')
            node_sizes.append(3000)
        else:
            node_colors.append('lightgreen')
            node_sizes.append(1000)
    
    # Draw edges with varying thickness based on number of shared connections
    edge_weights = [G[u][v].get('weight', 1) for u, v in G.edges()]
    
    nx.draw(G, pos,
            node_color=node_colors,
            node_size=node_sizes,
            with_labels=True,
            font_size=8,
            width=edge_weights,
            edge_color='gray',
            alpha=0.7)
    
    # Add legend
    legend_elements = [plt.Line2D([0], [0], marker='o', color='w', 
                                 markerfacecolor=c, label=l, markersize=10)
                      for c, l in [('red', 'Professors'),
                                 ('lightgreen', 'Shared Collaborators')]]
    plt.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 1))
    
    plt.title("Shared Connections Between Professors")
    plt.savefig("shared_connections_network.png", bbox_inches='tight')
    plt.close()

# %%
def print_shared_connections(G):
    """Print details of shared connections between professors"""
    print("\nShared Connections Analysis:")
    for (prof1, prof2) in G.edges():
        if G.nodes[prof1]['node_type'] == "professor" and G.nodes[prof2]['node_type'] == "professor":
            shared = G[prof1][prof2]['shared_coauthors']
            print(f"\n{prof1} and {prof2} share {len(shared)} coauthor(s):")
            for coauthor in shared:
                print(f"  - {coauthor}")

# %%
def analyze_network_statistics(G, professor_name):
    """Analyze network statistics for centrality and connectivity."""
    degree_centrality = nx.degree_centrality(G)
    closeness_centrality = nx.closeness_centrality(G)
    betweenness_centrality = nx.betweenness_centrality(G)
    eigenvector_centrality = nx.eigenvector_centrality(G, max_iter=1000, tol=1e-6)

    print(f"\nStatistical Measures for {professor_name}")
    print(f"Degree Centrality: {degree_centrality}")
    print(f"Closeness Centrality: {closeness_centrality}")
    print(f"Betweenness Centrality: {betweenness_centrality}")
    print(f"Eigenvector Centrality: {eigenvector_centrality}")

    # Plotting with adjusted bar width
    plt.figure(figsize=(12, 6))
    x = range(len(degree_centrality))
    
    plt.bar(x, degree_centrality.values(), color='blue', label='Degree Centrality', width=0.2)
    plt.bar(x, closeness_centrality.values(), color='green', label='Closeness Centrality', width=0.2)
    plt.bar(x, betweenness_centrality.values(), color='red', label='Betweenness Centrality', width=0.2)
    plt.bar(x, eigenvector_centrality.values(), color='purple', label='Eigenvector Centrality', width=0.2)
    
    plt.xticks(x, list(degree_centrality.keys()), rotation=45, ha='right')
    plt.legend()
    plt.title(f'Graph-Based Statistical Measures - {professor_name}')
    plt.tight_layout()
    plt.savefig(f"statistics_{professor_name.replace(' ', '_')}.png")
    plt.close()

# %%
# List of Google Scholar IDs (Replace with actual IDs)
scholar_ids = ["1Yl1h_YAAAAJ", "UBXqggoAAAAJ", "bmQ917cAAAAJ", "W4lc9bUAAAAJ", "OGQm6cwAAAAJ"]
    
# Extract all profiles
profiles = [extract_scholar_profile(scholar_id) for scholar_id in scholar_ids]

# Generate and save individual networks
print("Generating individual networks...")
for profile in profiles:
    if profile:
        G = create_individual_network(profile)
        visualize_individual_network(G, profile["name"])
        analyze_network_statistics(G, profile["name"])
        print(f"Created network for {profile['name']}")

# Generate and save shared connections network
print("\nAnalyzing shared connections...")
shared_G = find_shared_connections(profiles)
visualize_shared_network(shared_G)
print_shared_connections(shared_G)
# Out:
# Generating individual networks...
#
# Statistical Measures for Nitin Saxena
# Degree Centrality: {'Nitin Saxena': 1.0, 'Manindra Agrawal': 0.037037037037037035, 'Pranjal Dutta': 0.037037037037037035, 'Rohit Gurjar': 0.037037037037037035, 'Arpita Korwar': 0.037037037037037035, 'Gabor Ivanyos': 0.037037037037037035, 'C. Seshadhri': 0.037037037037037035, 'Chandan Saha': 0.037037037037037035, 'Marek Karpinski': 0.037037037037037035, 'Ramprasad Saptharishi': 0.037037037037037035, 'Sumanta Ghosh': 0.037037037037037035, 'Ashish Dwivedi': 0.037037037037037035, 'Igor Shparlinski': 0.037037037037037035, 'Prateek Dwivedi': 0.037037037037037035, 'Simone Severini': 0.037037037037037035, 'Rajat Mittal': 0.037037037037037035, 'Zeyu Guo': 0.037037037037037035, 'Pranav Bisht': 0.037037037037037035, 'CS Bhargav': 0.037037037037037035, 'Lajos Rónyai': 0.037037037037037035, 'Miklos Santha': 0.037037037037037035, 'Angshuman Karmakar': 0.037037037037037035, 'Vishwas Bhargava': 0.037037037037037035, 'Devansh Shringi': 0.037037037037037035, 'Madhavan Mukund': 0.037037037037037035, 'Shubham Sahai': 0.037037037037037035, 'Amit  Sinhababu': 0.037037037037037035, 'Anindya Ganguly': 0.037037037037037035}
# Closeness Centrality: {'Nitin Saxena': 1.0, 'Manindra Agrawal': 0.5094339622641509, 'Pranjal Dutta': 0.5094339622641509, 'Rohit Gurjar': 0.5094339622641509, 'Arpita Korwar': 0.5094339622641509, 'Gabor Ivanyos': 0.5094339622641509, 'C. Seshadhri': 0.5094339622641509, 'Chandan Saha': 0.5094339622641509, 'Marek Karpinski': 0.5094339622641509, 'Ramprasad Saptharishi': 0.5094339622641509, 'Sumanta Ghosh': 0.5094339622641509, 'Ashish Dwivedi': 0.5094339622641509, 'Igor Shparlinski': 0.5094339622641509, 'Prateek Dwivedi': 0.5094339622641509, 'Simone Severini': 0.5094339622641509, 'Rajat Mittal': 0.5094339622641509, 'Zeyu Guo': 0.5094339622641509, 'Pranav Bisht': 0.5094339622641509, 'CS Bhargav': 0.5094339622641509, 'Lajos Rónyai': 0.5094339622641509, 'Miklos Santha': 0.5094339622641509, 'Angshuman Karmakar': 0.5094339622641509, 'Vishwas Bhargava': 0.5094339622641509, 'Devansh Shringi': 0.5094339622641509, 'Madhavan Mukund': 0.5094339622641509, 'Shubham Sahai': 0.5094339622641509, 'Amit  Sinhababu': 0.5094339622641509, 'Anindya Ganguly': 0.5094339622641509}
# Betweenness Centrality: {'Nitin Saxena': 1.0, 'Manindra Agrawal': 0.0, 'Pranjal Dutta': 0.0, 'Rohit Gurjar': 0.0, 'Arpita Korwar': 0.0, 'Gabor Ivanyos': 0.0, 'C. Seshadhri': 0.0, 'Chandan Saha': 0.0, 'Marek Karpinski': 0.0, 'Ramprasad Saptharishi': 0.0, 'Sumanta Ghosh': 0.0, 'Ashish Dwivedi': 0.0, 'Igor Shparlinski': 0.0, 'Prateek Dwivedi': 0.0, 'Simone Severini': 0.0, 'Rajat Mittal': 0.0, 'Zeyu Guo': 0.0, 'Pranav Bisht': 0.0, 'CS Bhargav': 0.0, 'Lajos Rónyai': 0.0, 'Miklos Santha': 0.0, 'Angshuman Karmakar': 0.0, 'Vishwas Bhargava': 0.0, 'Devansh Shringi': 0.0, 'Madhavan Mukund': 0.0, 'Shubham Sahai': 0.0, 'Amit  Sinhababu': 0.0, 'Anindya Ganguly': 0.0}
# Eigenvector Centrality: {'Nitin Saxena': 0.7071080236286205, 'Manindra Agrawal': 0.13608252437944576, 'Pranjal Dutta': 0.13608252437944576, 'Rohit Gurjar': 0.13608252437944576, 'Arpita Korwar': 0.13608252437944576, 'Gabor Ivanyos': 0.13608252437944576, 'C. Seshadhri': 0.13608252437944576, 'Chandan Saha': 0.13608252437944576, 'Marek Karpinski': 0.13608252437944576, 'Ramprasad Saptharishi': 0.13608252437944576, 'Sumanta Ghosh': 0.13608252437944576, 'Ashish Dwivedi': 0.13608252437944576, 'Igor Shparlinski': 0.13608252437944576, 'Prateek Dwivedi': 0.13608252437944576, 'Simone Severini': 0.13608252437944576, 'Rajat Mittal': 0.13608252437944576, 'Zeyu Guo': 0.13608252437944576, 'Pranav Bisht': 0.13608252437944576, 'CS Bhargav': 0.13608252437944576, 'Lajos Rónyai': 0.13608252437944576, 'Miklos Santha': 0.13608252437944576, 'Angshuman Karmakar': 0.13608252437944576, 'Vishwas Bhargava': 0.13608252437944576, 'Devansh Shringi': 0.13608252437944576, 'Madhavan Mukund': 0.13608252437944576, 'Shubham Sahai': 0.13608252437944576, 'Amit  Sinhababu': 0.13608252437944576, 'Anindya Ganguly': 0.13608252437944576}
# Created network for Nitin Saxena
#
# Statistical Measures for Manindra Agrawal
# Degree Centrality: {'Manindra Agrawal': 1.0, 'Nitin Saxena': 0.03571428571428571, 'VIkraman Arvind': 0.03571428571428571, 'Eric Allender': 0.03571428571428571, 'PS Thiagarajan': 0.03571428571428571, 'Mathukumalli Vidyasagar': 0.03571428571428571, 'Steven Rudich': 0.03571428571428571, 'Chandan Saha': 0.03571428571428571, 'Rohit Gurjar': 0.03571428571428571, 'Vinay V': 0.03571428571428571, 'Ramprasad Saptharishi': 0.03571428571428571, 'Kasper Green Larsen': 0.03571428571428571, 'peyman afshani': 0.03571428571428571, 'Kurt Mehlhorn': 0.03571428571428571, 'Carola Doerr': 0.03571428571428571, 'Osamu Watanabe': 0.03571428571428571, 'Samir Datta': 0.03571428571428571, 'Sumanta Ghosh': 0.03571428571428571, 'Arpita Korwar': 0.03571428571428571, 'Benjamin Doerr': 0.03571428571428571, 'Frank Stephan': 0.03571428571428571, 'Richard Beigel': 0.03571428571428571, 'S Akshay': 0.03571428571428571, 'S Barry Cooper': 0.03571428571428571, 'Prabal Pratap Singh': 0.03571428571428571, 'Avaneesh Singh': 0.03571428571428571, 'Lance Fortnow': 0.03571428571428571, 'Satyadev Nandakumar': 0.03571428571428571, 'Diptarka Chakraborty': 0.03571428571428571}
# Closeness Centrality: {'Manindra Agrawal': 1.0, 'Nitin Saxena': 0.509090909090909, 'VIkraman Arvind': 0.509090909090909, 'Eric Allender': 0.509090909090909, 'PS Thiagarajan': 0.509090909090909, 'Mathukumalli Vidyasagar': 0.509090909090909, 'Steven Rudich': 0.509090909090909, 'Chandan Saha': 0.509090909090909, 'Rohit Gurjar': 0.509090909090909, 'Vinay V': 0.509090909090909, 'Ramprasad Saptharishi': 0.509090909090909, 'Kasper Green Larsen': 0.509090909090909, 'peyman afshani': 0.509090909090909, 'Kurt Mehlhorn': 0.509090909090909, 'Carola Doerr': 0.509090909090909, 'Osamu Watanabe': 0.509090909090909, 'Samir Datta': 0.509090909090909, 'Sumanta Ghosh': 0.509090909090909, 'Arpita Korwar': 0.509090909090909, 'Benjamin Doerr': 0.509090909090909, 'Frank Stephan': 0.509090909090909, 'Richard Beigel': 0.509090909090909, 'S Akshay': 0.509090909090909, 'S Barry Cooper': 0.509090909090909, 'Prabal Pratap Singh': 0.509090909090909, 'Avaneesh Singh': 0.509090909090909, 'Lance Fortnow': 0.509090909090909, 'Satyadev Nandakumar': 0.509090909090909, 'Diptarka Chakraborty': 0.509090909090909}
# Betweenness Centrality: {'Manindra Agrawal': 1.0, 'Nitin Saxena': 0.0, 'VIkraman Arvind': 0.0, 'Eric Allender': 0.0, 'PS Thiagarajan': 0.0, 'Mathukumalli Vidyasagar': 0.0, 'Steven Rudich': 0.0, 'Chandan Saha': 0.0, 'Rohit Gurjar': 0.0, 'Vinay V': 0.0, 'Ramprasad Saptharishi': 0.0, 'Kasper Green Larsen': 0.0, 'peyman afshani': 0.0, 'Kurt Mehlhorn': 0.0, 'Carola Doerr': 0.0, 'Osamu Watanabe': 0.0, 'Samir Datta': 0.0, 'Sumanta Ghosh': 0.0, 'Arpita Korwar': 0.0, 'Benjamin Doerr': 0.0, 'Frank Stephan': 0.0, 'Richard Beigel': 0.0, 'S Akshay': 0.0, 'S Barry Cooper': 0.0, 'Prabal Pratap Singh': 0.0, 'Avaneesh Singh': 0.0, 'Lance Fortnow': 0.0, 'Satyadev Nandakumar': 0.0, 'Diptarka Chakraborty': 0.0}
# Eigenvector Centrality: {'Manindra Agrawal': 0.7071083681046862, 'Nitin Saxena': 0.13363032105620015, 'VIkraman Arvind': 0.13363032105620015, 'Eric Allender': 0.13363032105620015, 'PS Thiagarajan': 0.13363032105620015, 'Mathukumalli Vidyasagar': 0.13363032105620015, 'Steven Rudich': 0.13363032105620015, 'Chandan Saha': 0.13363032105620015, 'Rohit Gurjar': 0.13363032105620015, 'Vinay V': 0.13363032105620015, 'Ramprasad Saptharishi': 0.13363032105620015, 'Kasper Green Larsen': 0.13363032105620015, 'peyman afshani': 0.13363032105620015, 'Kurt Mehlhorn': 0.13363032105620015, 'Carola Doerr': 0.13363032105620015, 'Osamu Watanabe': 0.13363032105620015, 'Samir Datta': 0.13363032105620015, 'Sumanta Ghosh': 0.13363032105620015, 'Arpita Korwar': 0.13363032105620015, 'Benjamin Doerr': 0.13363032105620015, 'Frank Stephan': 0.13363032105620015, 'Richard Beigel': 0.13363032105620015, 'S Akshay': 0.13363032105620015, 'S Barry Cooper': 0.13363032105620015, 'Prabal Pratap Singh': 0.13363032105620015, 'Avaneesh Singh': 0.13363032105620015, 'Lance Fortnow': 0.13363032105620015, 'Satyadev Nandakumar': 0.13363032105620015, 'Diptarka Chakraborty': 0.13363032105620015}
# Created network for Manindra Agrawal
#
# Statistical Measures for Vijay Kumar Jain
# Degree Centrality: {'Vijay Kumar Jain': 1.0, 'Ajay Sidpara': 0.08333333333333333, 'Prof. Neelesh Kumar Jain': 0.08333333333333333, 'Sounak Choudhury': 0.08333333333333333, 'Prof. (Dr.) Vinod Yadava': 0.08333333333333333, 'Dr. Dayanand Shrinivas Bilgi': 0.08333333333333333, 'Vishal Dhamgaye': 0.08333333333333333, 'Yogesh M. Joshi,': 0.08333333333333333, 'Kalyanmoy Deb': 0.08333333333333333, 'Subodh Kalia': 0.08333333333333333, 'Rakesh Mote': 0.08333333333333333, 'Prem Kumar Kalra': 0.08333333333333333, 'G.S. Lodha': 0.08333333333333333}
# Closeness Centrality: {'Vijay Kumar Jain': 1.0, 'Ajay Sidpara': 0.5217391304347826, 'Prof. Neelesh Kumar Jain': 0.5217391304347826, 'Sounak Choudhury': 0.5217391304347826, 'Prof. (Dr.) Vinod Yadava': 0.5217391304347826, 'Dr. Dayanand Shrinivas Bilgi': 0.5217391304347826, 'Vishal Dhamgaye': 0.5217391304347826, 'Yogesh M. Joshi,': 0.5217391304347826, 'Kalyanmoy Deb': 0.5217391304347826, 'Subodh Kalia': 0.5217391304347826, 'Rakesh Mote': 0.5217391304347826, 'Prem Kumar Kalra': 0.5217391304347826, 'G.S. Lodha': 0.5217391304347826}
# Betweenness Centrality: {'Vijay Kumar Jain': 1.0, 'Ajay Sidpara': 0.0, 'Prof. Neelesh Kumar Jain': 0.0, 'Sounak Choudhury': 0.0, 'Prof. (Dr.) Vinod Yadava': 0.0, 'Dr. Dayanand Shrinivas Bilgi': 0.0, 'Vishal Dhamgaye': 0.0, 'Yogesh M. Joshi,': 0.0, 'Kalyanmoy Deb': 0.0, 'Subodh Kalia': 0.0, 'Rakesh Mote': 0.0, 'Prem Kumar Kalra': 0.0, 'G.S. Lodha': 0.0}
# Eigenvector Centrality: {'Vijay Kumar Jain': 0.7071059613076448, 'Ajay Sidpara': 0.20412438191030963, 'Prof. Neelesh Kumar Jain': 0.20412438191030963, 'Sounak Choudhury': 0.20412438191030963, 'Prof. (Dr.) Vinod Yadava': 0.20412438191030963, 'Dr. Dayanand Shrinivas Bilgi': 0.20412438191030963, 'Vishal Dhamgaye': 0.20412438191030963, 'Yogesh M. Joshi,': 0.20412438191030963, 'Kalyanmoy Deb': 0.20412438191030963, 'Subodh Kalia': 0.20412438191030963, 'Rakesh Mote': 0.20412438191030963, 'Prem Kumar Kalra': 0.20412438191030963, 'G.S. Lodha': 0.20412438191030963}
# Created network for Vijay Kumar Jain
#
# Statistical Measures for Prof. (Dr.) Vinod Yadava
# Degree Centrality: {'Prof. (Dr.) Vinod Yadava': 1.0, 'Amit Sharma': 0.047619047619047616, 'Audhesh Narayan': 0.047619047619047616, 'Dr. Gyanendra Kumar Singh': 0.047619047619047616, 'Sanjay Mishra': 0.047619047619047616, 'Dr. KB Judal': 0.047619047619047616, 'Vijay Kumar Jain': 0.047619047619047616, 'Dr. Rajesh Kumar Porwal': 0.047619047619047616, 'Dr. Basanta Kumar Bhuyan': 0.047619047619047616, 'Param Singh': 0.047619047619047616, 'Prof. Janakarajan Ramkumar': 0.047619047619047616, 'Dayanidhi K Pathak': 0.047619047619047616, 'Dr. Praveen Kumar Rai': 0.047619047619047616, 'Prof. Sanjeev Kumar Singh Yadav': 0.047619047619047616, 'Dr. Balaji PS': 0.047619047619047616, 'Dr. Ram Singar Yadav': 0.047619047619047616, 'Nandani Singh': 0.047619047619047616, 'Pragya Shandilya': 0.047619047619047616, 'Rahul S Mulik': 0.047619047619047616, 'ANJANI KUMAR SINGH': 0.047619047619047616, 'Himadri Pandey, Ph.D.': 0.047619047619047616, 'Dr. Pallvita Yadav': 0.047619047619047616}
# Closeness Centrality: {'Prof. (Dr.) Vinod Yadava': 1.0, 'Amit Sharma': 0.5121951219512195, 'Audhesh Narayan': 0.5121951219512195, 'Dr. Gyanendra Kumar Singh': 0.5121951219512195, 'Sanjay Mishra': 0.5121951219512195, 'Dr. KB Judal': 0.5121951219512195, 'Vijay Kumar Jain': 0.5121951219512195, 'Dr. Rajesh Kumar Porwal': 0.5121951219512195, 'Dr. Basanta Kumar Bhuyan': 0.5121951219512195, 'Param Singh': 0.5121951219512195, 'Prof. Janakarajan Ramkumar': 0.5121951219512195, 'Dayanidhi K Pathak': 0.5121951219512195, 'Dr. Praveen Kumar Rai': 0.5121951219512195, 'Prof. Sanjeev Kumar Singh Yadav': 0.5121951219512195, 'Dr. Balaji PS': 0.5121951219512195, 'Dr. Ram Singar Yadav': 0.5121951219512195, 'Nandani Singh': 0.5121951219512195, 'Pragya Shandilya': 0.5121951219512195, 'Rahul S Mulik': 0.5121951219512195, 'ANJANI KUMAR SINGH': 0.5121951219512195, 'Himadri Pandey, Ph.D.': 0.5121951219512195, 'Dr. Pallvita Yadav': 0.5121951219512195}
# Betweenness Centrality: {'Prof. (Dr.) Vinod Yadava': 1.0, 'Amit Sharma': 0.0, 'Audhesh Narayan': 0.0, 'Dr. Gyanendra Kumar Singh': 0.0, 'Sanjay Mishra': 0.0, 'Dr. KB Judal': 0.0, 'Vijay Kumar Jain': 0.0, 'Dr. Rajesh Kumar Porwal': 0.0, 'Dr. Basanta Kumar Bhuyan': 0.0, 'Param Singh': 0.0, 'Prof. Janakarajan Ramkumar': 0.0, 'Dayanidhi K Pathak': 0.0, 'Dr. Praveen Kumar Rai': 0.0, 'Prof. Sanjeev Kumar Singh Yadav': 0.0, 'Dr. Balaji PS': 0.0, 'Dr. Ram Singar Yadav': 0.0, 'Nandani Singh': 0.0, 'Pragya Shandilya': 0.0, 'Rahul S Mulik': 0.0, 'ANJANI KUMAR SINGH': 0.0, 'Himadri Pandey, Ph.D.': 0.0, 'Dr. Pallvita Yadav': 0.0}
# Eigenvector Centrality: {'Prof. (Dr.) Vinod Yadava': 0.7071079569156933, 'Amit Sharma': 0.15430309339653162, 'Audhesh Narayan': 0.15430309339653162, 'Dr. Gyanendra Kumar Singh': 0.15430309339653162, 'Sanjay Mishra': 0.15430309339653162, 'Dr. KB Judal': 0.15430309339653162, 'Vijay Kumar Jain': 0.15430309339653162, 'Dr. Rajesh Kumar Porwal': 0.15430309339653162, 'Dr. Basanta Kumar Bhuyan': 0.15430309339653162, 'Param Singh': 0.15430309339653162, 'Prof. Janakarajan Ramkumar': 0.15430309339653162, 'Dayanidhi K Pathak': 0.15430309339653162, 'Dr. Praveen Kumar Rai': 0.15430309339653162, 'Prof. Sanjeev Kumar Singh Yadav': 0.15430309339653162, 'Dr. Balaji PS': 0.15430309339653162, 'Dr. Ram Singar Yadav': 0.15430309339653162, 'Nandani Singh': 0.15430309339653162, 'Pragya Shandilya': 0.15430309339653162, 'Rahul S Mulik': 0.15430309339653162, 'ANJANI KUMAR SINGH': 0.15430309339653162, 'Himadri Pandey, Ph.D.': 0.15430309339653162, 'Dr. Pallvita Yadav': 0.15430309339653162}
# Created network for Prof. (Dr.) Vinod Yadava
#
# Statistical Measures for Dharmender Singh Kushwaha
# Degree Centrality: {'Dharmender Singh Kushwaha': 1.0, 'SHAKTI MISHRA': 0.05263157894736842, 'Dr. Amrendra Singh Yadav': 0.05263157894736842, 'manu vardhan': 0.05263157894736842, 'Ashish Sharma': 0.05263157894736842, 'Rohit K Sachan': 0.05263157894736842, 'Dr. Tarun Kumar': 0.05263157894736842, 'Dushyant Kumar Singh': 0.05263157894736842, 'Sanjeev Pippal': 0.05263157894736842, 'Eva Patel': 0.05263157894736842, 'Aprna Tripathi': 0.05263157894736842, 'Nikita Singh': 0.05263157894736842, 'Dr Avinash Gupta': 0.05263157894736842, 'Himanshu Gahlot': 0.05263157894736842, 'Biru Rajak': 0.05263157894736842, 'Divya  Kumar': 0.05263157894736842, 'Dhirendra Kumar shukla': 0.05263157894736842, 'Ravindra Kumar Singh': 0.05263157894736842, 'Anurag Mishra': 0.05263157894736842, 'Alok Mathur': 0.05263157894736842}
# Closeness Centrality: {'Dharmender Singh Kushwaha': 1.0, 'SHAKTI MISHRA': 0.5135135135135135, 'Dr. Amrendra Singh Yadav': 0.5135135135135135, 'manu vardhan': 0.5135135135135135, 'Ashish Sharma': 0.5135135135135135, 'Rohit K Sachan': 0.5135135135135135, 'Dr. Tarun Kumar': 0.5135135135135135, 'Dushyant Kumar Singh': 0.5135135135135135, 'Sanjeev Pippal': 0.5135135135135135, 'Eva Patel': 0.5135135135135135, 'Aprna Tripathi': 0.5135135135135135, 'Nikita Singh': 0.5135135135135135, 'Dr Avinash Gupta': 0.5135135135135135, 'Himanshu Gahlot': 0.5135135135135135, 'Biru Rajak': 0.5135135135135135, 'Divya  Kumar': 0.5135135135135135, 'Dhirendra Kumar shukla': 0.5135135135135135, 'Ravindra Kumar Singh': 0.5135135135135135, 'Anurag Mishra': 0.5135135135135135, 'Alok Mathur': 0.5135135135135135}
# Betweenness Centrality: {'Dharmender Singh Kushwaha': 1.0, 'SHAKTI MISHRA': 0.0, 'Dr. Amrendra Singh Yadav': 0.0, 'manu vardhan': 0.0, 'Ashish Sharma': 0.0, 'Rohit K Sachan': 0.0, 'Dr. Tarun Kumar': 0.0, 'Dushyant Kumar Singh': 0.0, 'Sanjeev Pippal': 0.0, 'Eva Patel': 0.0, 'Aprna Tripathi': 0.0, 'Nikita Singh': 0.0, 'Dr Avinash Gupta': 0.0, 'Himanshu Gahlot': 0.0, 'Biru Rajak': 0.0, 'Divya  Kumar': 0.0, 'Dhirendra Kumar shukla': 0.0, 'Ravindra Kumar Singh': 0.0, 'Anurag Mishra': 0.0, 'Alok Mathur': 0.0}
# Eigenvector Centrality: {'Dharmender Singh Kushwaha': 0.7071058564776657, 'SHAKTI MISHRA': 0.16222163327325184, 'Dr. Amrendra Singh Yadav': 0.16222163327325184, 'manu vardhan': 0.16222163327325184, 'Ashish Sharma': 0.16222163327325184, 'Rohit K Sachan': 0.16222163327325184, 'Dr. Tarun Kumar': 0.16222163327325184, 'Dushyant Kumar Singh': 0.16222163327325184, 'Sanjeev Pippal': 0.16222163327325184, 'Eva Patel': 0.16222163327325184, 'Aprna Tripathi': 0.16222163327325184, 'Nikita Singh': 0.16222163327325184, 'Dr Avinash Gupta': 0.16222163327325184, 'Himanshu Gahlot': 0.16222163327325184, 'Biru Rajak': 0.16222163327325184, 'Divya  Kumar': 0.16222163327325184, 'Dhirendra Kumar shukla': 0.16222163327325184, 'Ravindra Kumar Singh': 0.16222163327325184, 'Anurag Mishra': 0.16222163327325184, 'Alok Mathur': 0.16222163327325184}
# Created network for Dharmender Singh Kushwaha
#
# Analyzing shared connections...
#
# Shared Connections Analysis:
#
# Nitin Saxena and Manindra Agrawal share 5 coauthor(s):
#   - Arpita Korwar
#   - Chandan Saha
#   - Ramprasad Saptharishi
#   - Rohit Gurjar
#   - Sumanta Ghosh
